# %%
from main import peaks_vs_thresholds
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
kid = 5
pread = 113
file_type = 'vis'
pw = 1500
pw_offset = 100
filter_type = 'exp'
lifetime = 200
fit_tqp = [200, 1000]

dir_on = r"D:\Data\LT218Chip1_BF_20221103_MIR3_8\12KIDs mono on 3800 long\TD_Power"
chuncksize = 10
noise_mph = 5
pulse_mph = 16
doubles_fraction = 4
nr_stds = [3, 14]
nr_chuncks = [1, 1]

# %%
pulses = peaks_vs_thresholds(dir_on, kid, pread, file_type, noise_mph, pulse_mph, pw, pw_offset, lifetime, nr_stds, 
                             nr_chuncks, chuncksize, filter_type, fit_tqp, doubles_fraction=doubles_fraction)

# %%
kid = 5
pread = 113
file_type = 'vis'
pw = 1500
pw_offset = 100
filter_type = 'exp'
lifetime = 250
fit_tqp = [200, 1000]

dir_on = r"D:\Data\LT218Chip1_BF_20221025_MIR8_5\12KIDs mono off long\TD_Power"
chuncksize = 20
noise_mph = 5
pulse_mph = 14
doubles_fraction = 2
nr_stds = [3, 10]
nr_chuncks = [1, 1]

# %%
pulses = peaks_vs_thresholds(dir_on, kid, pread, file_type, noise_mph, pulse_mph, pw, pw_offset, lifetime, nr_stds, 
                             nr_chuncks, chuncksize, filter_type, fit_tqp, doubles_fraction=doubles_fraction)
# Out:
# Secondaries/Outliers/Total = 8/39/267
# Optimal filter constructed with 228 pulses and 10000 noise segments
# Analysed 20 out of 20 files
# Analysed 20 out of 20 files
# Secondaries/Outliers/Total = 7/49/385
# Nr of neg pulses at lowest threshold: 51
#
# R = 4.39, Rsn = 10.48, 336 pulses
# tqp = 251 +- 1.1 us
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
kid = 5
pread = 113
file_type = 'vis'
pw = 1500
pw_offset = 100
filter_type = 'exp'
lifetime = 275
fit_tqp = [200, 1000]

dir_on = r"D:\Data\LT218Chip1_BF_20240116_MIR18_5\KID5_all_temps\180K"
chuncksize = 10
noise_mph = 5
pulse_mph = 5
doubles_fraction = 2
nr_stds = [5]
nr_chuncks = [None]

# %%
pulses = peaks_vs_thresholds(dir_on, kid, pread, file_type, noise_mph, pulse_mph, pw, pw_offset, lifetime, nr_stds, 
                             nr_chuncks, chuncksize, filter_type, fit_tqp, doubles_fraction=doubles_fraction)

# %%
kid = 5
pread = 109
file_type = 'vis'
pw = 1500
pw_offset = 100
filter_type = 'exp'
lifetime = 320
fit_tqp = [200, 1000]

dir_on = r"D:\Data\LT218Chip1_ADR_20240506_MIR24\12KIDs_3Pread_TD40s_1MHz_BB24K\TD_Power"
chuncksize = 20
noise_mph = 5
pulse_mph = 5
doubles_fraction = 5
nr_stds = [5]
nr_chuncks = [1]
binsize = 0.035

# %%
pulses = peaks_vs_thresholds(dir_on, kid, pread, file_type, noise_mph, pulse_mph, pw, pw_offset, lifetime, nr_stds, 
                             nr_chuncks, chuncksize, filter_type, fit_tqp, binsize=binsize, doubles_fraction=doubles_fraction)

# %%
kid = 24
pread = 115
file_type = 'vis'
pw = 400
pw_offset = 20
filter_type = 'exp'
lifetime = 75
fit_tqp = [50, 300]

dir_on = r"D:\Data\LT218Chip1_ADR_20240506_MIR24\12KIDs_3Pread_TD40s_1MHz_BB24K\TD_Power"
chuncksize = 40
noise_mph = 5
pulse_mph = 5
doubles_fraction = 6
nr_stds = [5]
nr_chuncks = [1]
binsize = 0.035

# %%
pulses = peaks_vs_thresholds(dir_on, kid, pread, file_type, noise_mph, pulse_mph, pw, pw_offset, lifetime, nr_stds, 
                             nr_chuncks, chuncksize, filter_type, fit_tqp, binsize=binsize, doubles_fraction=doubles_fraction)

# %%
kid = 23
pread = 111
file_type = 'vis'
pw = 300
pw_offset = 20
filter_type = 'exp'
lifetime = 50
fit_tqp = [50, 100]

dir_on = r"D:\Data\LT218Chip1_ADR_20240506_MIR24\12KIDs_3Pread_TD40s_1MHz_BB24K\TD_Power"
chuncksize = 40
noise_mph = 5
pulse_mph = 5
doubles_fraction = 2
nr_stds = [5]
nr_chuncks = [1]
binsize = 0.035
pulses = peaks_vs_thresholds(dir_on, kid, pread, file_type, noise_mph, pulse_mph, pw, pw_offset, lifetime, nr_stds, 
                             nr_chuncks, chuncksize, filter_type, fit_tqp, binsize=binsize, doubles_fraction=doubles_fraction)

# %%
np.load('figures/LT218_27f0s_design.npy')

# %%
kid = 21
pread = 115
file_type = 'vis'
pw = 300
pw_offset = 20
filter_type = 'exp'
lifetime = 50
fit_tqp = [50, 100]

dir_on = r"D:\Data\LT218Chip1_ADR_20240506_MIR24\12KIDs_3Pread_TD40s_1MHz_BB26K\TD_Power"
chuncksize = 40
noise_mph = 5
pulse_mph = 5
doubles_fraction = 3
nr_stds = [5]
nr_chuncks = [1]
binsize = 0.035
pulses = peaks_vs_thresholds(dir_on, kid, pread, file_type, noise_mph, pulse_mph, pw, pw_offset, lifetime, nr_stds, 
                             nr_chuncks, chuncksize, filter_type, fit_tqp, binsize=binsize, doubles_fraction=doubles_fraction)

# %%
kid = 20
pread = 111
file_type = 'vis'
pw = 300
pw_offset = 20
filter_type = 'exp'
lifetime = 30
fit_tqp = [50, 100]

dir_on = r"D:\Data\LT218Chip1_ADR_20240506_MIR24\12KIDs_3Pread_TD40s_1MHz_BB24K\TD_Power"
chuncksize = 40
noise_mph = 5
pulse_mph = 5
doubles_fraction = 2
nr_stds = [16.5]
nr_chuncks = [1]
binsize = 0.035
pulses = peaks_vs_thresholds(dir_on, kid, pread, file_type, noise_mph, pulse_mph, pw, pw_offset, lifetime, nr_stds, 
                             nr_chuncks, chuncksize, filter_type, fit_tqp, binsize=binsize, doubles_fraction=doubles_fraction)
